# %%
# !pip install transformers
# !pip install torch
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# ...

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import torch

tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

prompt =  "How to make vegan curry ?"
model_inputs = tokenizer(prompt, return_tensors="pt")
print(model_inputs)


generated_ids = model.generate(**model_inputs, max_new_tokens=100, do_sample=True)
tokenizer.batch_decode(generated_ids)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# ...

# %%
tokenizer.batch_decode(generated_ids)
# Out:
# ['How to make vegan curry?\n\nKale Salad is one of my most versatile vegan curry recipes that you can make yourself with any kale you wish.\n\nI would make this in batches before dinner and serve it with some kar-aloo. So easy!\n\nI make most of my vegan curry in a slow cooker, so it is easy to pour off any veggies that might spoil. My friend is also one of my best cumin pickers. So if you are wondering what to add that will']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
dataset = pd.read_csv('/content/drive/MyDrive/Data.txt',on_bad_lines='skip',header=None, names=['prompt', 'label'])

# %%
dataset.head()
# Out:
#                                               prompt                    label
# 0                                    What is a proxy   and how can I use one?
# 1  What song has the lyrics "someone left the cak...                      NaN
# 2  I am the owner of an adult website called http...                      NaN
# 3  Does the Bible mention anything about a place ...                      NaN
# 4  What are useful free and open-source tools for...                      NaN

# %%
dataset.shape
# Out:
# (27, 2)

# %%
prompts = dataset.prompt.values
prompts

# %%
data = dataset.prompt.copy()
data
# Out:
# 0                                       What is a proxy
# 1     What song has the lyrics "someone left the cak...
# 2     I am the owner of an adult website called http...
# 3     Does the Bible mention anything about a place ...
# 4     What are useful free and open-source tools for...
# 5     The justice department has told the state of M...
# 6     Why are the Kardashians so popular? Why are pe...
# 7     How fast could the US Air Force SR-71 Blackbir...
# 8     Did a landlord ever offer to lower your rent s...
# 9       Can you check phase rotation with a multimeter?
# 10                        How does malaria infect dogs?
# 11              What are the best ways to invest money?
# 12                What is the reason for the 4 seasons?
# 13    How difficult was it for you to find your life...
# 14    How do people who eat only once or twice a day...
# 15            Can you take control of your blood sugar?
# 16    What is the best opening sentence you have rea...
# ...

# %%
from torch.utils.data import DataLoader


tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

train_dataloader = DataLoader(data, batch_size=1, shuffle=True)
for prompt in train_dataloader:

  model_inputs = tokenizer(prompt, return_tensors="pt")
  generated_ids = model.generate(**model_inputs, max_new_tokens=100,pad_token_id=tokenizer.eos_token_id,do_sample=True)

# %%
tokenizer.batch_decode(generated_ids)
# Out:
# ['What song has the lyrics "someone left the cake out in the rain"? What song has the song, "that was the first time that I heard my own mom," that sorta sings like it was written by somebody from the world outside the world? And I wanted to see what sort of lyrics she is speaking before I started singing. And then I came back to it. She said, "I want to know what mom meant before I started singing."\n\nAnd so I put a little song on there and told her, "No, I am not talking about']

# %%
# file = open("Data.txt","w+")

# for line in ds['train'][:30]['question']:
#   file.writelines(line)
#   f
# file.close()
# file = open("Data.txt","r")

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import torch

tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# %%
#from torch.utils.data import Dataset

# %%
# max_length = 64
# class GPT2Dataset(Dataset):

#     def __init__(self, txt_list, tokenizer, gpt2_type='gpt2'):
#         self.tokenizer = tokenizer
#         self.inputs = []
#         self.labels = []
#         self.attention_masks =[]

#         for txt in txt_list:
#           encodings_dict = tokenizer('<|startoftext|>' + txt +'<|endoftxt|>')
#           self.input_ids = encodings_dict['input_ids']
#           self.attention_masks = encodings_dict['attention_masks']
#           self.inputs.append(torch.tensor(self.input_ids))
#           self.attention_masks.append(torch.tensor(self.self.attention_masks))

#     def __len__(self):
#           return len(self.inputs)

#     def __getitem__(self,i):
#           #return self.inputs[i], self.labels[i]
#           return self.inputs[i], self.attention_masks[i]

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel
from torch.utils.data import DataLoader
import torch

tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')

train_dataloader = DataLoader(data, batch_size=1, shuffle=True)
for prompt in train_dataloader:
  #prompt = '<|startoftext|>' + prompt[0] +'<|endoftext|>'
  model_inputs = tokenizer(prompt, return_tensors="pt")
  generated_ids = model.generate(**model_inputs, max_new_tokens=100,pad_token_id=tokenizer.eos_token_id)

# %%
tokenizer.batch_decode(generated_ids)
